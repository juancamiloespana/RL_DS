# %%
from google.colab import drive
import sys
import os

drive.mount('/content/drive')  ### conect to drive
path='/content/drive/MyDrive/cod/RL_DS'
os.chdir(path) ### setting a Working directory on drive path
sys.path.append(path+'/')  ###setting path to read user defined functions
# Out:
# Mounted at /content/drive

# %%
df_agrupado = df.groupby(["Nivel E", "Nivel fac", "Corrida"])["y"]
mean_y = df_agrupado.mean()
std_y = df_agrupado.std()
n = df_agrupado.count()

# %%
# prompt: to this code: compute percentile 97.5 and 2.5: df_agrupado = df.groupby(["Nivel E", "Nivel fac", "Corrida"])["y"]
# mean_y = df_agrupado.mean()
